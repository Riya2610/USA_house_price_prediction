# %%
#importing required libraries
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
print("Original DataFrame:")
print(data.info())
# Out:
# Original DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              4992 non-null   float64
#  1   Avg. Area House Age           4962 non-null   float64
#  2   Avg. Area Number of Rooms     4979 non-null   float64
#  3   Avg. Area Number of Bedrooms  4993 non-null   float64
#  4   Area Population               4972 non-null   float64
#  5   Price                         4978 non-null   float64
#  6   Address                       4997 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB
# None

# %%
#loading the data set

data= pd.read_csv("/Users/nandan/Desktop/USA.csv")
data.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159                  NaN                        NaN
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
data.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
columns_with_missing_values = ["Avg. Area House Age", "Avg. Area Number of Rooms", "Avg. Area Number of Bedrooms", "Area Population"]
data_cleaned = data.dropna(subset=columns_with_missing_values)

# %%
print("\nCleaned DataFrame:")
print(data_cleaned.info())
# Out:
# Cleaned DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4917 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              4909 non-null   float64
#  1   Avg. Area House Age           4917 non-null   float64
#  2   Avg. Area Number of Rooms     4917 non-null   float64
#  3   Avg. Area Number of Bedrooms  4917 non-null   float64
#  4   Area Population               4917 non-null   float64
#  5   Price                         4898 non-null   float64
#  6   Address                       4915 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 307.3+ KB
# None

# %%
data_cleaned.to_csv("/Users/nandan/Desktop/Clean.csv", index=False)

# %%
#loading clean the data set

data= pd.read_csv("/Users/nandan/Desktop/Clean.csv")
data.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      64698.463428             6.025336                   8.147760
# 6      78394.339278             6.989780                   6.620478
# 7      59927.660813             5.362126                   6.393121
# 8      81885.927184             4.423672                   8.167688
# 9      80527.472083             8.093513                   5.042747
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...
